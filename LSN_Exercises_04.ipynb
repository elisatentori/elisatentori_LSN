# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 4</span>

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import FontProperties
import numpy as np
import math

# %%
def PlotObs(e1,e2,e3,t1,T,title_e,title_T):
    
    n=len(e1)
    x=np.arange(n)
    
    fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2,figsize=(16,5))
    
    ax0.plot(x, e1, label='U',color='purple')
    ax0.plot(x, e2, label='K',color='orange')
    ax0.plot(x, e3, label='E_tot',color='green')
    legend = ax0.legend(loc='center right', fontsize='x-large')
    frame = legend.get_frame()
    frame.set_facecolor('white')
    frame.set_edgecolor('black')
    ax0.set_title(title_e,color='C0',fontsize=15)
    ax0.set_xlabel('# steps')
    ax0.set_ylabel('E     [Reduced units]')
    ax0.grid(alpha=0.4)
    
    x_coordinates = [0, 1000]
    y_coordinates = [T, T]
    ax1.plot(x_coordinates,y_coordinates)
    ax1.plot(x,t1)
    ax1.set_title(title_T,color='C0',fontsize=15)
    ax1.set_xlabel('# steps \n')
    ax1.set_ylabel('T    [Reduced units]')
    ax1.grid(alpha=0.4)
    
    plt.show()

# %%
def PlotReStart(x,y,i,T,temp):
    font = FontProperties()
    #font.set_family('serif')
    font.set_name('Times New Roman')
    l=int(i/4)
    m=int(4*(i/4-int(i/4)))
    x_coordinates = [0, 100]
    y_coordinates = [T, T]
    axs[l][m].plot(x_coordinates,y_coordinates, label=temp)   # plotta T=1.4 (T desiderata)
    axs[l][m].plot(x,y,label='T_'+str(i+1))                           # plotta l'andamento di T di ogni simulazione da 1000 steps
    axs[l][m].set_xlabel('# steps', fontproperties=font)
    axs[l][m].set_ylabel('\nT    [Reduced units]', fontproperties=font)
    legend = axs[l][m].legend(loc='upper right',fancybox=True, framealpha=0.5, prop={'size': 10},fontsize='x-large')
    axs[l][m].grid(alpha=0.4)
    #axs[l][m].set_xlim(5, 4)
    axs[l][m].set_title('\nSimulation n.'+str(i+1),color='C0',fontsize=15)

# %%
def PlotMC(y1,err1,y2,err2,y3,err3,y4,err4):
    fig, ((ax0, ax1),(ax2, ax3)) = plt.subplots(nrows=2, ncols=2,figsize=(15,10))
    
    font = FontProperties()
    #font.set_family('serif')
    font.set_name('Times New Roman')
    
    x = np.arange(100)
    ax0.errorbar(x,y1,yerr=err1)
    ax0.set_title('U / N ', color='C0', fontsize=14)
    ax0.set_ylabel('U / N   [Reduced units]', fontproperties=font)
    ax0.set_xlabel('blocks', fontproperties=font)
    ax0.grid(alpha=0.4)
    
    ax1.errorbar(x,y2,yerr=err2)
    ax1.set_title('K / N', color='C0', fontsize=14)
    ax1.set_ylabel('\n \n K / N    [Reduced units] ', fontproperties=font)
    ax1.set_xlabel('blocks', fontproperties=font)
    ax1.grid(alpha=0.4)
    
    ax2.errorbar(x,y3,yerr=err3)
    ax2.set_title('\n $E_{tot}$ / N ', color='C0', fontsize=14)
    ax2.set_ylabel('$E_{tot}$ / N   [Reduced units]', fontproperties=font)
    ax2.set_xlabel('blocks', fontproperties=font)
    ax2.grid(alpha=0.4)
    
    ax3.errorbar(x,y4,yerr=err4)
    ax3.set_title('\n Temperature', color='C0', fontsize=14)
    ax3.set_ylabel('\n \n T   [Reduced units]', fontproperties=font)
    ax3.set_xlabel('blocks', fontproperties=font)
    ax3.grid(alpha=0.4)

    fig.tight_layout()
    plt.show()

# %%
def graph(y1,err1,y2,err2,y3,err3,y4,err4,y5,err5,r6,y6,err6,phase):
    fig, ((ax0, ax1),(ax2, ax3),(ax4, ax5)) = plt.subplots(nrows=3, ncols=2,figsize=(16,15))
    
    font = FontProperties()
    font.set_name('Times New Roman')
    
    x = np.arange(100)
    ax0.errorbar(x,y1,yerr=err1)
    ax0.set_title('U / N - '+phase, color='C0', fontsize=14)
    ax0.set_ylabel('U / N  [J]',fontproperties=font)
    ax0.set_xlabel('blocks',fontproperties=font)
    ax0.grid(alpha=0.4)
    
    ax1.errorbar(x,y2,yerr=err2)
    ax1.set_title('K / N - '+phase, color='C0', fontsize=14)
    ax1.set_ylabel('\n K / N  [J]',fontproperties=font)
    ax1.set_xlabel('blocks',fontproperties=font)
    ax1.grid(alpha=0.4)
    
    ax2.errorbar(x,y3,yerr=err3)
    ax2.set_title('\n $E_{tot}$ / N - '+phase, color='C0', fontsize=14)
    ax2.set_ylabel('$E_{tot}$ / N  [J]',fontproperties=font)
    ax2.set_xlabel('blocks',fontproperties=font)
    ax2.grid(alpha=0.4)
    
    ax3.errorbar(x,y4,yerr=err4)
    ax3.set_title('\n T - '+phase, color='C0', fontsize=14)
    ax3.set_ylabel('\n T [K]',fontproperties=font)
    ax3.set_xlabel('blocks',fontproperties=font)
    ax3.grid(alpha=0.4)
    
    ax4.errorbar(x,y5,yerr=err5)
    ax4.set_title('\n P - '+phase, color='C0', fontsize=14)
    ax4.set_ylabel('P [Pa]',fontproperties=font)
    ax4.set_xlabel('blocks',fontproperties=font)
    ax4.grid(alpha=0.4)
    
    ax5.fill_between(r6, y6 - err6, y6 + err6, alpha=1.,color='lightgreen')
    ax5.errorbar(r6,y6,yerr=err6,linewidth = 0.6)
    ax5.set_title('\n g(r) - '+phase, color='C0', fontsize=14)
    ax5.set_ylabel('\n g(r)',fontproperties=font)
    ax5.set_xlabel('r',fontproperties=font)
    ax5.grid(alpha=0.4)

    fig.tight_layout()
    plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### <b>Exercise 04.1</b>
#
# The Molecular Dynamics (MD) code starts the simulation run from a provided spatial configuration of the $N$ particles (file: <font face="Courier">config.0</font>) and, once the simulation is finished, it writes out the final configuration (file: <font face="Courier">config.final</font>).
# 1. <span style="color:red">Improve the MD code by enabling (you should insert this option via a boolean-like variable in the input file) the **possibility** to **(re)start** reading not only a **actual** spatial configuration [$\vec{r}(t)$] file but also an **old** spatial configuration [$\vec{r}(t-dt)$] file</span> (files: <font face="Courier">old.0</font> and <font face="Courier">old.final</font>).
# 2. Moreover, <span style="color:red">add the possibility to rescale the velocities [i.e. to correct $\vec{r}(t-dt)$] in order to match a desired temperature</span>.
# 3. In your report, put some pictures which show that you have been able to equilibrate the thermodynamic phases at the beginning of your simulations.
#
# The typical required operations when the re-start option will be enabled are:
# 1. read $\vec{r}(t)$ and $\vec{r}(t-dt)$ from the corresponding input files
# 2. compute $\vec{r}(t+dt)$ with one step of the Verlet algorithm; with $\vec{r}(t+dt)$ and $\vec{r}(t)$ compute $\vec{v}(t+dt/2)$; finally obtain the actual temperature $T(t+dt/2)$
# 3. by comparing $T(t+dt/2)$ with the desired/target temperature  $T^\star$ extract a scaling factor for the velocities and rescale them: $\vec{v}(t) \to \vec{v}_s(t)$
# 4. use $\vec{v}_s(t)$ to estimate a novel **old** spatial configuration: $\vec{r}_{new}(t) = \vec{r}(t+dt) - dt \vec{v}_s$
# 5. use $\vec{r}_{new}(t)$ and $\vec{r}(t+dt)$ to start the simulation
# 6. Do not forget to use **periodic boundary contitions** every time it is appropriate!
#
# This will help you, especially in the equilibration phases of your simulations.
# <br>

# %% [markdown]
# ### <font face = "Tahoma" style="color:teal"><b>Caduta di T per il sistema non termalizzato</b></font>
#
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     <br>
#     Parto verificando come funziona il codice dato a lezione con una simulazione da $10^3$ steps del sistema non termalizzato.
#     <br>
#     <br>
#     </p>

# %%
epot = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_term/output_epot.dat')
ekin = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_term/output_ekin.dat')
etot = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_term/output_etot.dat')
temp = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_term/output_temp.dat')
PlotObs(epot,ekin,etot,temp,1.4,'\nNon-thermalized system','\nNon-thermalized system')
sum=0
for i in range(1000):
    sum += temp[i]
print('<T>: ',sum/1000)
# Out:
# <T>:  0.7239373509999999

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Come si nota dal grafico, c'è un'iniziale caduta dell'energia cinetica e di T. Dopo i primi steps la temperatura si assesta attorno a un valore molto più basso di $T=1.4$.
#     </p>
# <br>

# %% [markdown]
# ### <font face = "Tahoma" style="color:teal"><b>Termalizzazione del sistema</b></font>
#
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Ho inizialmente modificato il codice MD fornito a lezione, aggiungendo solamente la possibilità di stampare sia l'ultima che la penultima configurazione del sistema, rispettivamente nei file <font face="Courier">config.final</font> e <font face="Courier">old.final</font> (vedi <i>/Lecture04/01_Initial</i>). Utilizzando tale codice, ho dunque avviato una brevissima simulazione (da 2 soli steps), che, partendo da una configurazione fcc e da una temperatura $T$ fornita dal file <i>input.dat</i>, stampa l'ultima e la penultima configurazione, ovvero i due file che userò come input di partenza per termalizzare il sistema tramite il "<i>metodo di re-start</i>".
#     </p>
#
# Ho poi modificato il codice (vedi <i>/Lecture04/02_ReStart</i>) inserendo la possibilità di:
# - leggere le configurazioni di input ai tempi t-dt e t (cioè i files <font face="Courier">config.0</font> e <font face="Courier">old.0</font>)
# - calcolare la prima velocità con Verlet: $v(t+\frac{dt}{2})=\frac{r(t-dt)-r(t)}{dt}$
# - calcolare la temperatura del sistema $T(t+\frac{dt}{2})$ e compararla con la temperatura desiderata $T^*$ per dedurre il fattore di scala
# - riscalare le velocità tramite il fattore di scala $\vec{v}(t) \to \vec{v}_s(t)$
# - usare $v_s(t)$ per stimare una nuova "<i>vecchia</i> configurazione spaziale": $\vec{r}_{new}(t) = \vec{r}(t+dt) - dt\cdot \vec{v}_s$
# - usare $\vec{r}_{new}(t)$ e $\vec{r}(t+dt)$ per iniziare una simulazione
#
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Dopo ciò ho creato uno script in bash (<font face="Courier">termalizzazione.sh</font>) che si occupa di far avviare consecutivamente alcune simulazioni da 100 steps; ogni simulazione legge come configurazioni di input le ultime due della simulazione precedente ("<i>metodo di re-start</i>").<br>
#     Ho storato per ogni simulazione i file che riportano l'evoluzione di <i>energia totale, energia potenziale, energia cinetica e temperatura</i>. Il metodo in questione è da utilizzarsi finchè la temperatura del sistema non si assesta attorno a un valor medio prossimo al valore desiderato.
#     </p>
#
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     In questo caso ho settato in <font face="Courier">input.solid</font> una temperatura desiderata $T=1.4$ (<b>non è la temperatura adatta per simulare l'Argon solido, ho usato questa temperatura per puro scopo didattico negli esercizi 1 e 2, per verificare se il codice fin qui implementato porti il sistema ad equilibrarsi a una temperatura desiderata</b>).
#     <br> <br>
#     Ho svolto in tutto 19 simulazioni di cui riporto ora i grafici. Si può notare da essi - e dalle medie di T stampate - che nelle ultime quattro il valore di T si assesta intorno alla temperatura desiderata.
#     </p>

# %%
x = np.arange(100)
fig, axs = plt.subplots(5,4,figsize=(15, 17), sharey=True,tight_layout=True)
print('TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS \n')
for i in range(19):
    v = np.loadtxt(fname='Lecture04/Esercizio1/thermalisationT1.4/'+str(i+1)+'_temp.dat')
    sum=0
    for j in range(100):
        sum += v[j]
    print('Simulation n.',str(i+1),'  <T>=',sum/100)
    PlotReStart(x,v,i,1.4,'T=1.4')   # richiamo la funzione che grafica la T della simulaz. i-esima
print('\nGRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 1000 STEPS \n')
plt.show()
# Out:
# TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS
#
# Simulation n. 1   <T>= 1.1046867000000005
# Simulation n. 2   <T>= 1.2699071999999993
# Simulation n. 3   <T>= 1.3435857000000007
# Simulation n. 4   <T>= 1.4373683000000002
# Simulation n. 5   <T>= 1.4579230999999995
# Simulation n. 6   <T>= 1.4196247000000002
# Simulation n. 7   <T>= 1.3625974999999997
# Simulation n. 8   <T>= 1.3463837
# Simulation n. 9   <T>= 1.4091049999999998
# Simulation n. 10   <T>= 1.3853459000000001
# Simulation n. 11   <T>= 1.3292017
# Simulation n. 12   <T>= 1.3590022000000004
# Simulation n. 13   <T>= 1.3933905000000002
# Simulation n. 14   <T>= 1.3521254999999996
# Simulation n. 15   <T>= 1.4651639999999997
# Simulation n. 16   <T>= 1.3900812
# Simulation n. 17   <T>= 1.399831499999999
# Simulation n. 18   <T>= 1.3799162
# Simulation n. 19   <T>= 1.4171829
#
# GRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 1000 STEPS

# %% [markdown]
# <br>

# %% [markdown]
# ### <font face = "Tahoma" style="color:teal"><b>Dopo una corretta termalizzazione il sistema si assesta alla T voluta</b></font>
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Per mezzo del codice MD modificato come sopra, avvio una simulazione da $10^3$ steps, le cui configurazioni di input sono rispettivamente le configurazioni finali dopo 19 re-starting.
#     </p>

# %%
epot19 = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_MC_19/output_epot.dat')
ekin19 = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_MC_19/output_ekin.dat')
etot19 = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_MC_19/output_etot.dat')
temp19 = np.loadtxt(fname='Lecture04/Esercizio1/simulazione_non_MC_19/output_temp.dat')
PlotObs(epot19,ekin19,etot19,temp19,1.4,' \n    Simulation with $10^3$ steps after $19$ re-start thermalization \n',' ')

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Si nota che, usando come input le due configurazioni finali dopo 19 re-start, la simulazione mantiene una temperatura media $T \approx 1.41$, ovvero una temperatura vicina a quella desiderata.
#     <br>
#     L'energia totale è inoltre ben conservata: l'algoritmo di Verlet ha buone proprietà di conservazione dell'energia.
#     </p>
#
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     <b>Concludo che la termalizzazione tramite re-start ha risolto bene il problema iniziale della caduta della temperatura.</b>
#     </p>
# <br>

# %% [markdown]
# ### <b>Exercise 04.2</b>
#
# The Molecular Dynamics code we have provided prints out only instantaneous values for the total (internal) energy per particle, $E/N$, potential energy per particle, $U/N$, kinetic energy per particle, $K/N$, and temperature, $T$.
# Take the MD code and include block averaging:
#
# Divide the <span style="color:blue"><font face="Courier">nstep</font></span> of the simulation into <span style="color:blue"><font face="Courier">nblocks</font></span>. By exploiting these blocks, <span style="color:red">code the calculation of the average values and the uncertainties for $E/N$, $U/N$, $K/N$ and $T$</span>, that will be written in new specific output files, for example: <font face="Courier">ave_epot.out, ave_ekin.out, ave_etot.out, ave_temp.out</font></span>

# %% [markdown]
# ### <font face = "Tahoma" style="color:teal"><b>Simulazione Monte Carlo</b></font>
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Ho modificato il codice MD come richiesto (vedi <i>/Lecture04/MonteCarlo_NVE</i>). Per testarlo ho lanciato una simulazione di prova da 10000 steps (con metodo a blocchi), dandole in input le configurazioni (config.final e old.final) ottenute nell'esercizio $04.1$ per un sistema di particelle a $T=1.4$, previa termalizzazione (19 re-start). Ho così ottenuto i files <font face="Courier">ave_epot.out, ave_ekin.out, ave_etot.out, ave_temp.out</font></span>.
#     </p>
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Nei grafici che seguono sono riportate le medie progressive di $\frac{E_{tot}}{N}$, $\frac{U}{N}$, $\frac{K}{N}$, e $T$ in unità ridotte con le rispettive barre di errore.
#     </p>

# %%
u = np.loadtxt(fname='Lecture04/Esercizio2/output.epot.0',usecols=2)
err_u = np.loadtxt(fname='Lecture04/Esercizio2/output.epot.0',usecols=3)

k = np.loadtxt(fname='Lecture04/Esercizio2/output.ekin.0',usecols=2)
err_k = np.loadtxt(fname='Lecture04/Esercizio2/output.ekin.0',usecols=3)

e = np.loadtxt(fname='Lecture04/Esercizio2/output.etot.0',usecols=2)
err_e = np.loadtxt(fname='Lecture04/Esercizio2/output.etot.0',usecols=3)

t = np.loadtxt(fname='Lecture04/Esercizio2/output.temp.0',usecols=2)
err_t = np.loadtxt(fname='Lecture04/Esercizio2/output.temp.0',usecols=3)

PlotMC(u, err_u, k, err_k, e, err_e, t, err_t)

# %% [markdown]
# <br>

# %% [markdown]
# ### <b>Exercise 04.3</b>
#
# By means of your upgraded MD code, equilibrate and <span style="color:red">perform MD simulations via a Lennard-Jones model</span> of Argon ($\sigma = 0.34$ nm, $\epsilon/k_B = 120$ K, $m=39.948$ amu) in the following conditions:
# 1. solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# 2. liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# 3. gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)
#
# and show in pictures the obtained average values and uncertainties for the total (internal) energy per particle, $E/N$, the potential energy per particle, $U/N$, the kinetic energy per particle, $K/N$ and the temperature, $T$ ... in SI units!

# %%
k_b=1.38064852*10**(-23)
epsilon=120*k_b
sigma=0.346680637*10**(-9) 
mass=39.948
print('epsilon: ',epsilon)
# Out:
# epsilon:  1.6567782239999999e-21

# %% [markdown]
# ### <font face = "Tahoma" style="color:teal"><b>Simulazione Monte Carlo</b></font>
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Per simulare le tre fasi dell'Argon ho effettuato tre distinte simulazioni da $10^6$ steps con metodo a blocchi. Ognuna di esse prende in input le configurazioni (config.final e old.final) ottenute tramite equilibrazione alla $T$ della fase desiderata.
#     </p>
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Per ogni fase riporto sia i grafici dell'equilibrazione sia quelli di $\frac{E_{tot}}{N}$, $\frac{U}{N}$, $\frac{K}{N}$, $T$, $P$ e $g(r)$ con le rispettive barre di errore, in unità SI.
#     </p>

# %% [markdown]
# <br>

# %% [markdown]
# ## <font face = "Tahoma" style="color:teal"><b>Argon - fase solida:</b></font>

# %% [markdown]
# ### Equilibrazione

# %%
x = np.arange(100)
fig, axs = plt.subplots(3,4,figsize=(17, 10), sharey=True,tight_layout=True)
print('TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS \n')
for i in range(12):
    v = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/thermalisation/'+str(i+1)+'_temp.dat')
    sum=0
    for j in range(100):
        sum += v[j]
    print('Simulation n.',str(i+1),'  <T>=',sum/100)
    PlotReStart(x,v,i,0.8,'T=0.8')
#fig.suptitle('Thermalization Plotting')
print('\nGRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 100 STEPS \n')
plt.show()
# Out:
# TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS
#
# Simulation n. 1   <T>= 0.4074001499999999
# Simulation n. 2   <T>= 0.6220665200000002
# Simulation n. 3   <T>= 0.72787661
# Simulation n. 4   <T>= 0.7662233200000003
# Simulation n. 5   <T>= 0.7734632900000002
# Simulation n. 6   <T>= 0.80160331
# Simulation n. 7   <T>= 0.7740338600000001
# Simulation n. 8   <T>= 0.8115192000000002
# Simulation n. 9   <T>= 0.7949573199999999
# Simulation n. 10   <T>= 0.8302870200000001
# Simulation n. 11   <T>= 0.7932008700000001
# Simulation n. 12   <T>= 0.8004439899999997
#
# GRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 100 STEPS

# %% [markdown]
# ### <b>Simulazione</b>

# %%
u_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.epot.0',usecols=2)*epsilon
err_u_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.epot.0',usecols=3)*epsilon

k_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.ekin.0',usecols=2)*epsilon
err_k_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.ekin.0',usecols=3)*epsilon

e_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.etot.0',usecols=2)*epsilon
err_e_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.etot.0',usecols=3)*epsilon

t_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.temp.0',usecols=2)*120
err_t_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.temp.0',usecols=3)*120

p_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.pres.0',usecols=2)*(epsilon/sigma**3)
err_p_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.pres.0',usecols=3)*(epsilon/sigma**3)

r_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.gave.0',usecols=0)
gav_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.gave.0',usecols=1)
err_gav_s = np.loadtxt(fname='Lecture04/Esercizio3/01_solid/gofr_solid/output.gave.0',usecols=2)

graph(u_s, err_u_s, k_s, err_k_s, e_s, err_e_s, t_s, err_t_s, p_s, err_p_s, r_s, gav_s, err_gav_s,'SOLID PHASE')

# %%
print('< U / N > = ',u_s[99],' +/- ',err_u_s[99])
print('< K / N > = ',k_s[99],' +/- ',err_k_s[99])
print('< Etot / N > = ',e_s[99],' +/- ',err_e_s[99])
print('< P > = ',p_s[99],' +/- ',err_p_s[99])
print('< T > = ',t_s[99],' +/- ',err_t_s[99])
# Out:
# < U / N > =  -1.2497409499276799e-20  +/-  2.3441589413553595e-25
# < K / N > =  1.95211551021024e-21  +/-  2.0681893925836796e-25
# < Etot / N > =  -9.11564349179472e-21  +/-  5.572441014166079e-26
# < P > =  302608687.48107916  +/-  35348.30451269843
# < T > =  94.2606  +/-  0.00998658

# %% [markdown]
# <br>

# %% [markdown]
# ## <font face = "Tahoma" style="color:teal"><b>Argon - fase liquida:</b></font>

# %% [markdown]
# ### Equilibrazione

# %%
x = np.arange(100)
fig, axs = plt.subplots(4,4,figsize=(17, 12), sharey=True,tight_layout=True)
print('TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS \n')
for i in range(16):
    v = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/thermalisation/'+str(i+1)+'_temp.dat')
    sum=0
    for j in range(100):
        sum += v[j]
    print('simulazione n.',str(i+1),'  <T>=',sum/100)
    PlotReStart(x,v,i,1.1,'T=1.1')
print('\nGRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 100 STEPS \n')
plt.show()
# Out:
# TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS
#
# simulazione n. 1   <T>= 0.8180852800000001
# simulazione n. 2   <T>= 0.9626700800000002
# simulazione n. 3   <T>= 0.9965707399999999
# simulazione n. 4   <T>= 1.0560752899999994
# simulazione n. 5   <T>= 1.05540639
# simulazione n. 6   <T>= 1.0323767400000008
# simulazione n. 7   <T>= 1.0523439099999998
# simulazione n. 8   <T>= 1.0640920000000003
# simulazione n. 9   <T>= 1.03574904
# simulazione n. 10   <T>= 1.06939048
# simulazione n. 11   <T>= 1.1519544000000002
# simulazione n. 12   <T>= 1.1704742000000001
# simulazione n. 13   <T>= 1.07652157
# simulazione n. 14   <T>= 1.0636376499999998
# simulazione n. 15   <T>= 1.1433183999999996
# simulazione n. 16   <T>= 1.10393021
#
# GRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 100 STEPS

# %% [markdown]
# ### <b>Simulazione</b>

# %%
u_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.epot.0',usecols=2)*epsilon
err_u_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.epot.0',usecols=3)*epsilon

k_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.ekin.0',usecols=2)*epsilon
err_k_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.ekin.0',usecols=3)*epsilon

e_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.etot.0',usecols=2)*epsilon
err_e_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.etot.0',usecols=3)*epsilon

t_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.temp.0',usecols=2)*120
err_t_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.temp.0',usecols=3)*120

p_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.pres.0',usecols=2)*(epsilon/sigma**3)
err_p_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.pres.0',usecols=3)*(epsilon/sigma**3)

r_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.gave.0',usecols=0)
gav_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.gave.0',usecols=1)
err_gav_l = np.loadtxt(fname='Lecture04/Esercizio3/02_liquid/gofr_liquid/output.gave.0',usecols=2)

graph(u_l, err_u_l, k_l, err_k_l, e_l, err_e_l, t_l, err_t_l, p_l, err_p_l, r_l, gav_l, err_gav_l,'LIQUID PHASE')

# %%
print('< U / N > = ',u_l[99],' +/- ',err_u_l[99])
print('< K / N > = ',k_l[99],' +/- ',err_k_l[99])
print('< Etot / N > = ',e_l[99],' +/- ',err_e_l[99])
print('< P > = ',p_l[99],' +/- ',err_p_l[99])
print('< T > = ',t_l[99],' +/- ',err_t_l[99])
# Out:
# < U / N > =  -8.97102332062176e-21  +/-  1.5773655301672319e-24
# < K / N > =  2.84574854867136e-21  +/-  1.537524984214704e-24
# < Etot / N > =  -5.415593819699999e-21  +/-  1.0610372237705278e-25
# < P > =  64924897.344804645  +/-  215618.2875465351
# < T > =  137.412  +/-  0.07424172000000001

# %% [markdown]
# <br>

# %% [markdown]
# ## <font face = "Tahoma" style="color:teal"><b>Argon - fase gassosa:</b></font>

# %% [markdown]
# ### Equilibrazione

# %%
x = np.arange(100)
fig, axs = plt.subplots(7,4,figsize=(17, 22), sharey=True,tight_layout=True)
print('TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS \n')
for i in range(28):
    v = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/thermalisation/'+str(i+1)+'_temp.dat')
    sum=0
    for j in range(100):
        sum += v[j]
    print('Simulation n.',str(i+1),'  <T>=',sum/100)
    PlotReStart(x,v,i,1.2,'T=1.2')
print('\nGRAFICI DELL`ANDAMENTO DELLA TEMPERATURA PER OGNI SIMULAZIONE DA 100 STEPS \n')
plt.show()
# Out:
# TEMPERATURE MEDIE PER OGNI SIMULAZIONE DA 100 STEPS
#
# Simulation n. 1   <T>= 1.2160688000000008
# Simulation n. 2   <T>= 1.2486597
# Simulation n. 3   <T>= 1.217795
# Simulation n. 4   <T>= 1.2065214000000004
# Simulation n. 5   <T>= 1.2200901000000004
# Simulation n. 6   <T>= 1.2504874999999998
# Simulation n. 7   <T>= 1.2238975000000005
# Simulation n. 8   <T>= 1.2135128000000004
# Simulation n. 9   <T>= 1.2120194000000002
# Simulation n. 10   <T>= 1.1861617999999998
# Simulation n. 11   <T>= 1.2070319999999997
# Simulation n. 12   <T>= 1.2053520999999998
# Simulation n. 13   <T>= 1.1945799999999998
# Simulation n. 14   <T>= 1.1820444
# Simulation n. 15   <T>= 1.1911494000000002
# Simulation n. 16   <T>= 1.1924374000000006
# Simulation n. 17   <T>= 1.1992382999999998
# Simulation n. 18   <T>= 1.1981645000000003
# Simulation n. 19   <T>= 1.2089470000000002
# Simulation n. 20   <T>= 1.2241051
# Simulation n. 21   <T>= 1.1762314
# Simulation n. 22   <T>= 1.2017214
# ...

# %% [markdown]
# ### <b>Simulazione</b>

# %%
u_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.epot.0',usecols=2)*epsilon
err_u_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.epot.0',usecols=3)*epsilon

k_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.ekin.0',usecols=2)*epsilon
err_k_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.ekin.0',usecols=3)*epsilon

e_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.etot.0',usecols=2)*epsilon
err_e_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.etot.0',usecols=3)*epsilon

t_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.temp.0',usecols=2)*120
err_t_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.temp.0',usecols=3)*120

p_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.pres.0',usecols=2)*(epsilon/sigma**3)
err_p_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.pres.0',usecols=3)*(epsilon/sigma**3)

r_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.gave.0',usecols=0)
gav_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.gave.0',usecols=1)
err_gav_g = np.loadtxt(fname='Lecture04/Esercizio3/03_gas/gofr_gas/output.gave.0',usecols=2)

graph(u_g, err_u_g, k_g, err_k_g, u_g+k_g, err_e_g, t_g, err_t_g, p_g, err_p_g, r_g, gav_g, err_gav_g,'GASEOUS PHASE')

# %%
print('< U / N > = ',u_g[99],' +/- ',err_u_g[99])
print('< K / N > = ',k_g[99],' +/- ',err_k_g[99])
print('< Etot / N > = ',e_g[99],' +/- ',err_e_g[99])
print('< P > = ',p_g[99],' +/- ',err_p_g[99])
print('< T > = ',t_g[99],' +/- ',err_t_g[99])
# Out:
# < U / N > =  -6.74321991393792e-22  +/-  5.09946396677856e-24
# < K / N > =  2.9533728621023997e-21  +/-  5.0948912588803196e-24
# < Etot / N > =  2.2846143319847995e-21  +/-  1.090227999299184e-26
# < P > =  1957731.3286484003  +/-  4284.428493763941
# < T > =  142.60799999999998  +/-  0.2460144

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Nelle cartelle <i>/DATA/Lecture04/Esercizio3/01_solid</i>, <i>/DATA/Lecture04/Esercizio3/02_liquid</i>, <i>/DATA/Lecture04/Esercizio3/03_gas</i> sono presenti i file di animazione contenenti alcuni frame delle 3 simulazioni.
#     </p>

# %% [markdown]
# ### <span style="color:green"> Optional exercise</span>
#
# Include the calculation of the pressure, $P$, inside your Molecular Dynamics code: istantaneous values, average values and uncertainties.
#
# Remember that, via the **virial theorem**, the pressure in a Lennard-Jones system can be estimated by means of:
#
# $$ P = \rho k_B T + \frac{1}{3V} \left\langle \sum_{i=1}^{N-1} \sum_{j\,(>i)}^N 48\epsilon \left[ \left(\frac{\sigma}{|\vec{r}_i -\vec{r}_j|}\right)^{12} -
# \frac{1}{2} \left(\frac{\sigma}{|\vec{r}_i -\vec{r}_j|}\right)^6 \right] \right\rangle $$

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     Nelle codice <i>/Lecture04/Esercizio3/MonteCarlo_NVE</i>, ho inserito anche il calcolo della pressione e di g(r).
#     </p>
